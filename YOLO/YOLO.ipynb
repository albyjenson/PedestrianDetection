# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 50.8 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from ultralytics import YOLO

# %%
model= YOLO("yolov8m.pt")
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 254MB/s]

# %%
model.train(data="/content/drive/MyDrive/pedestrain detection/YOLO/data.yaml", epochs=10)
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer= YOLO("/content/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/pedestrain detection/YOLO/test/images", save= True, save_txt= True)
# Out:
# image 1/232 /content/drive/MyDrive/pedestrain detection/YOLO/test/images/000001_jpg.rf.988473f30508e474e5227e3c6f44d427.jpg: 640x640 3 persons, 39.2ms
# image 2/232 /content/drive/MyDrive/pedestrain detection/YOLO/test/images/000010_jpg.rf.e934b0f8142791552f5f7dbf2867cb3f.jpg: 640x640 1 nonhuman, 37.1ms
# image 3/232 /content/drive/MyDrive/pedestrain detection/YOLO/test/images/000022_jpg.rf.bf461512f286c9b6b2a05befb02996f3.jpg: 640x640 2 nonhumans, 38.6ms
# image 4/232 /content/drive/MyDrive/pedestrain detection/YOLO/test/images/000025_jpg.rf.d808c38154fa2d1f2d9a7cc91abbaf79.jpg: 640x640 2 nonhumans, 6 persons, 37.2ms
# image 5/232 /content/drive/MyDrive/pedestrain detection/YOLO/test/images/000027_jpg.rf.978512a119f829dbea60d5f168b078cf.jpg: 640x640 2 persons, 37.1ms
# image 6/232 /content/drive/MyDrive/pedestrain detection/YOLO/test/images/000038_jpg.rf.58e4b0e8adbaffb9ee993a7e34627f97.jpg: 640x640 (no detections), 37.1ms
# ...

# %%
# !pip install shutil
# Out:
# ERROR: Could not find a version that satisfies the requirement shutil (from versions: none)
# ERROR: No matching distribution found for shutil

# %%
import shutil
# Define paths
results_folder_colab = "/content/runs/detect/predict"
results_folder_drive = "/content/drive/MyDrive/pedestrain detection/YOLO/results"

shutil.move(results_folder_colab, results_folder_drive)
# Out:
# '/content/drive/MyDrive/pedestrain detection/YOLO/results/predict'

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !yolo detect predict model="/content/drive/MyDrive/pedestrain detection/YOLO/best (1).pt" source="/content/drive/MyDrive/pedestrain detection/2863232-uhd_3840_2160_30fps (1).mp4"
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/1 (frame 1/789) /content/drive/MyDrive/pedestrain detection/2863232-uhd_3840_2160_30fps (1).mp4: 384x640 2 persons, 957.6ms
# video 1/1 (frame 2/789) /content/drive/MyDrive/pedestrain detection/2863232-uhd_3840_2160_30fps (1).mp4: 384x640 2 persons, 1417.8ms
# video 1/1 (frame 3/789) /content/drive/MyDrive/pedestrain detection/2863232-uhd_3840_2160_30fps (1).mp4: 384x640 2 persons, 1421.7ms
# video 1/1 (frame 4/789) /content/drive/MyDrive/pedestrain detection/2863232-uhd_3840_2160_30fps (1).mp4: 384x640 4 persons, 1234.0ms
# video 1/1 (frame 5/789) /content/drive/MyDrive/pedestrain detection/2863232-uhd_3840_2160_30fps (1).mp4: 384x640 1 person, 853.9ms
# video 1/1 (frame 6/789) /content/drive/MyDrive/pedestrain detection/2863232-uhd_3840_2160_30fps (1).mp4: 384x640 3 persons, 869.4ms
# ...

# %%
import moviepy.editor
moviepy.editor.ipython_display("/content/runs/detect/predict/855565-hd_1920_1080_24fps.avi")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/moviepy/video/io/html_tools.py in html_embed(clip, filetype, maxduration, rd_kwargs, center, **html_kwargs)
#     132         try:
# --> 133             ext = exts_htmltype[ext]
#     134         except:
#
# KeyError: 'avi'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-0f2ad882ddcb> in <cell line: 2>()
#       1 import moviepy.editor
# ----> 2 moviepy.editor.ipython_display("/content/runs/detect/predict/855565-hd_1920_1080_24fps.avi")
#
# /usr/local/lib/python3.10/dist-packages/moviepy/video/io/html_tools.py in ipython_display(clip, filetype, maxduration, t, fps, rd_kwargs, center, **html_kwargs)
#     218         clip = clip.to_ImageClip(t)
#     219
# ...
